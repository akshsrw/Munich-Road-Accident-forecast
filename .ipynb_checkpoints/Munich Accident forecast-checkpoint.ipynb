# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
accident_data= pd.read_csv('210619.csv')
accident_data
# Out:
#            MONATSZAHL             AUSPRAEGUNG  JAHR   MONAT   WERT  \
# 0      Alkoholunfälle               insgesamt  2021  202101    NaN
# 1      Alkoholunfälle               insgesamt  2021  202102    NaN
# 2      Alkoholunfälle               insgesamt  2021  202103    NaN
# 3      Alkoholunfälle               insgesamt  2021  202104    NaN
# 4      Alkoholunfälle               insgesamt  2021  202105    NaN
# ...               ...                     ...   ...     ...    ...
# 1990  Verkehrsunfälle  Verletzte und Getötete  2000  200008  647.0
# 1991  Verkehrsunfälle  Verletzte und Getötete  2000  200009  675.0
# 1992  Verkehrsunfälle  Verletzte und Getötete  2000  200010  615.0
# 1993  Verkehrsunfälle  Verletzte und Getötete  2000  200011  578.0
# 1994  Verkehrsunfälle  Verletzte und Getötete  2000  200012  515.0
#
#       VORJAHRESWERT  VERAEND_VORMONAT_PROZENT  VERAEND_VORJAHRESMONAT_PROZENT  \
# 0              28.0                       NaN                             NaN
# ...

# %%
## Remove extra columns
accident_data.drop(['VORJAHRESWERT','VERAEND_VORMONAT_PROZENT','VERAEND_VORJAHRESMONAT_PROZENT','ZWOELF_MONATE_MITTELWERT'], axis=1, inplace=True)
accident_data.head(20)
# Out:
#         MONATSZAHL AUSPRAEGUNG  JAHR   MONAT   WERT
# 0   Alkoholunfälle   insgesamt  2021  202101    NaN
# 1   Alkoholunfälle   insgesamt  2021  202102    NaN
# 2   Alkoholunfälle   insgesamt  2021  202103    NaN
# 3   Alkoholunfälle   insgesamt  2021  202104    NaN
# 4   Alkoholunfälle   insgesamt  2021  202105    NaN
# 5   Alkoholunfälle   insgesamt  2021  202106    NaN
# 6   Alkoholunfälle   insgesamt  2021  202107    NaN
# 7   Alkoholunfälle   insgesamt  2021  202108    NaN
# 8   Alkoholunfälle   insgesamt  2021  202109    NaN
# 9   Alkoholunfälle   insgesamt  2021  202110    NaN
# 10  Alkoholunfälle   insgesamt  2021  202111    NaN
# 11  Alkoholunfälle   insgesamt  2021  202112    NaN
# 12  Alkoholunfälle   insgesamt  2020   Summe  430.0
# 13  Alkoholunfälle   insgesamt  2020  202001   28.0
# 14  Alkoholunfälle   insgesamt  2020  202002   40.0
# 15  Alkoholunfälle   insgesamt  2020  202003   27.0
# 16  Alkoholunfälle   insgesamt  2020  202004   26.0
# ...

# %%
##Drop empty rows and 'Summe' row from MONAT 

accident_data.dropna(subset=['WERT'],inplace=True)
accident_data=accident_data[accident_data.MONAT.apply(lambda x: x.isnumeric())]
accident_data.head(20)
# Out:
#         MONATSZAHL AUSPRAEGUNG  JAHR   MONAT  WERT
# 13  Alkoholunfälle   insgesamt  2020  202001  28.0
# 14  Alkoholunfälle   insgesamt  2020  202002  40.0
# 15  Alkoholunfälle   insgesamt  2020  202003  27.0
# 16  Alkoholunfälle   insgesamt  2020  202004  26.0
# 17  Alkoholunfälle   insgesamt  2020  202005  40.0
# 18  Alkoholunfälle   insgesamt  2020  202006  49.0
# 19  Alkoholunfälle   insgesamt  2020  202007  58.0
# 20  Alkoholunfälle   insgesamt  2020  202008  46.0
# 21  Alkoholunfälle   insgesamt  2020  202009  46.0
# 22  Alkoholunfälle   insgesamt  2020  202010  34.0
# 23  Alkoholunfälle   insgesamt  2020  202011  23.0
# 24  Alkoholunfälle   insgesamt  2020  202012  13.0
# 26  Alkoholunfälle   insgesamt  2019  201901  22.0
# 27  Alkoholunfälle   insgesamt  2019  201902  28.0
# 28  Alkoholunfälle   insgesamt  2019  201903  34.0
# 29  Alkoholunfälle   insgesamt  2019  201904  36.0
# 30  Alkoholunfälle   insgesamt  2019  201905  39.0
# ...

# %%
##Drop first four characters from MONAT column

accident_data['MONAT']=accident_data['MONAT'].str[4:]
accident_data.head()
# Out:
# C:\Users\Welcome\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#         MONATSZAHL AUSPRAEGUNG  JAHR MONAT  WERT
# 13  Alkoholunfälle   insgesamt  2020    01  28.0
# 14  Alkoholunfälle   insgesamt  2020    02  40.0
# 15  Alkoholunfälle   insgesamt  2020    03  27.0
# 16  Alkoholunfälle   insgesamt  2020    04  26.0
# 17  Alkoholunfälle   insgesamt  2020    05  40.0

# %%
##Rename year and month 

accident_data=accident_data.rename(columns={'JAHR':'year', 'MONAT':'month'})
accident_data
# Out:
#            MONATSZAHL             AUSPRAEGUNG  year month   WERT
# 13     Alkoholunfälle               insgesamt  2020    01   28.0
# 14     Alkoholunfälle               insgesamt  2020    02   40.0
# 15     Alkoholunfälle               insgesamt  2020    03   27.0
# 16     Alkoholunfälle               insgesamt  2020    04   26.0
# 17     Alkoholunfälle               insgesamt  2020    05   40.0
# ...               ...                     ...   ...   ...    ...
# 1990  Verkehrsunfälle  Verletzte und Getötete  2000    08  647.0
# 1991  Verkehrsunfälle  Verletzte und Getötete  2000    09  675.0
# 1992  Verkehrsunfälle  Verletzte und Getötete  2000    10  615.0
# 1993  Verkehrsunfälle  Verletzte und Getötete  2000    11  578.0
# 1994  Verkehrsunfälle  Verletzte und Getötete  2000    12  515.0
#
# [1764 rows x 5 columns]

# %%
##Create a DATE column

accident_data['DATE'] = pd.to_datetime(accident_data[['year', 'month',]].assign(DAY=1))

accident_data.set_index('DATE',inplace=True)
accident_data
# Out:
#                  MONATSZAHL             AUSPRAEGUNG  year month   WERT
# DATE
# 2020-01-01   Alkoholunfälle               insgesamt  2020    01   28.0
# 2020-02-01   Alkoholunfälle               insgesamt  2020    02   40.0
# 2020-03-01   Alkoholunfälle               insgesamt  2020    03   27.0
# 2020-04-01   Alkoholunfälle               insgesamt  2020    04   26.0
# 2020-05-01   Alkoholunfälle               insgesamt  2020    05   40.0
# ...                     ...                     ...   ...   ...    ...
# 2000-08-01  Verkehrsunfälle  Verletzte und Getötete  2000    08  647.0
# 2000-09-01  Verkehrsunfälle  Verletzte und Getötete  2000    09  675.0
# 2000-10-01  Verkehrsunfälle  Verletzte und Getötete  2000    10  615.0
# 2000-11-01  Verkehrsunfälle  Verletzte und Getötete  2000    11  578.0
# 2000-12-01  Verkehrsunfälle  Verletzte und Getötete  2000    12  515.0
#
# [1764 rows x 5 columns]

# %%
accident_data['MONATSZAHL'].unique()  ##CHECK all the unique values in MONATSZAHL
# Out:
# array(['Alkoholunfälle', 'Fluchtunfälle', 'Verkehrsunfälle'], dtype=object)

# %%
## PLOT ALL VALUES INDIVIDUALLY

p=accident_data ## WORKING ON COPY OF DATASET
 
figure, axis = plt.subplots(3, 2,figsize=(15,10)) 


for ci, i in enumerate(['Alkoholunfälle','Fluchtunfälle','Verkehrsunfälle']):
    for cj, j in enumerate(['insgesamt','Verletzte und Getötete']):
        P=accident_data[(accident_data['MONATSZAHL']==i) & (accident_data['AUSPRAEGUNG']==j)]
        P.sort_values('DATE', inplace=True)
        axis[ci, cj].plot(P['WERT'],)
        axis[ci, cj].set_title('%s -- %s!' % (i, j))
plt.show()
# Out:
# C:\Users\Welcome\anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\Welcome\anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\Welcome\anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
##Seperate Training Dataset from the table

Dataset=accident_data[(accident_data['MONATSZAHL']=='Alkoholunfälle') & (accident_data['AUSPRAEGUNG']=='insgesamt')]
Dataset=Dataset[['WERT']]
Dataset.sort_values('DATE', inplace=True)
Dataset.head()
# Out:
#             WERT
# DATE
# 2000-01-01  78.0
# 2000-02-01  53.0
# 2000-03-01  73.0
# 2000-04-01  78.0
# 2000-05-01  96.0

# %%
## Checking the trend, seasonal behavior and Noise of the Dataset


from statsmodels.tsa.seasonal import seasonal_decompose 

seasonal = seasonal_decompose(Dataset,model='addition',period=12)
fig = plt.figure()  
fig = seasonal.plot()  
fig.set_size_inches(15, 10)

# %%
## The model has Seasonal behavour, First Decreasing then Increasing Trend and high coarseness of noise.
## Checking if the data is stationary or not with AdFuller test (although the graphs shows its not stationary)

from statsmodels.tsa.stattools import adfuller

test_result=adfuller(Dataset['WERT'])

def adfuller_test(sales):
    result=adfuller(sales)
    labels = ['ADF Test Statistic','p-value','#Lags Used','Number of Observations Used']
    for value,label in zip(result,labels):
        print(label+' : '+str(value) )
    if result[1] <= 0.05:
        print("strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data has no unit root and is stationary")
    else:
        print("weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary ")

# %%
adfuller_test(Dataset['WERT'])
# Out:
# ADF Test Statistic : -2.7784740406264907
# p-value : 0.06141499421706813
# #Lags Used : 13
# Number of Observations Used : 238
# weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary

# %%
## Since the dataset has seasonality we will remove the seasonality and again check for stability

Dataset['Seasonal First Difference']=Dataset['WERT']-Dataset['WERT'].shift(12)
Dataset.head(20)
# Out:
#             WERT  Seasonal First Difference
# DATE
# 2000-01-01  78.0                        NaN
# 2000-02-01  53.0                        NaN
# 2000-03-01  73.0                        NaN
# 2000-04-01  78.0                        NaN
# 2000-05-01  96.0                        NaN
# 2000-06-01  57.0                        NaN
# 2000-07-01  99.0                        NaN
# 2000-08-01  77.0                        NaN
# 2000-09-01  84.0                        NaN
# 2000-10-01  83.0                        NaN
# 2000-11-01  71.0                        NaN
# 2000-12-01  85.0                        NaN
# 2001-01-01  66.0                      -12.0
# 2001-02-01  49.0                       -4.0
# 2001-03-01  63.0                      -10.0
# 2001-04-01  68.0                      -10.0
# 2001-05-01  85.0                      -11.0
# 2001-06-01  68.0                       11.0
# 2001-07-01  71.0                      -28.0
# 2001-08-01  60.0                      -17.0

# %%
adfuller_test(Dataset['Seasonal First Difference'].dropna())
# Out:
# ADF Test Statistic : -3.3587287373519246
# p-value : 0.01244889026615171
# #Lags Used : 15
# Number of Observations Used : 224
# strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data has no unit root and is stationary

# %%
## Finding the Parameters of the model using PACF and ACF model

from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
fig = plt.figure(figsize=(15,10))
ax1 = fig.add_subplot(211)
fig = plot_acf(Dataset['Seasonal First Difference'].iloc[13:],lags=40,ax=ax1)
ax2 = fig.add_subplot(212)
fig = plot_pacf(Dataset['Seasonal First Difference'].iloc[13:],lags=40,ax=ax2)

# %%
Dataset.drop(['Seasonal First Difference'],axis=1,inplace=True)

# %%
## Splitting the test train dataset

from pmdarima.model_selection import train_test_split

train, test = train_test_split(Dataset, train_size=240)

# %%
# Training the Sarima model with pdq parameters as 2,2,2 and seasonal order 1,1,1,12

import statsmodels.api as sm

model=sm.tsa.statespace.SARIMAX(train.WERT,order=(2, 2, 2),seasonal_order=(1,1,1,12))
result=model.fit()
# Out:
# C:\Users\Welcome\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\Welcome\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\Welcome\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\Users\Welcome\anaconda3\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)

# %%
## Plot the forecast(24Months) and actual values

Dataset['forecast']=result.predict(start=228,end=252,dynamic=True)
Dataset[['WERT','forecast']].plot(figsize=(16,8))

##Save forecast of last 12 months in another dataframe
forecast=Dataset['forecast']
forecast=forecast[-12:]

# %%
## Calculate the mean square error of the last 12 months prediction.

RMSE=((forecast - test.WERT) ** 2).mean() ** .5
RMSE
# Out:
# 10.120564480992533

# %%
result.forecast('2021-02')[-1]
# Out:
# 25.145203556771

# %%
## Saving the model
import pickle
pickle.dump(result, open('model.pkl','wb'))

# %%
##Reload and test the model

model = pickle.load(open('model.pkl','rb'))
print(model.forecast('2021-02')[-1])
# Out:
# 25.145203556771
